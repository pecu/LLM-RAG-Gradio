# %% [markdown]
# # 後測用LLM
# * 請逐一執行每一個區塊直至最後，將會看到聊天視窗
# * 目前執行格執行完畢才可以往下一個執行格

# %%
! pip install -q -U pypdf faiss-cpu
! pip install -q -U InstructorEmbedding
! pip install huggingface_hub -q
! pip install gradio -q
! pip install langchain==0.1.2 
! pip install sentence_transformers==2.2.2
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Requirement already satisfied: langchain==0.1.2 in ./anaconda3/lib/python3.10/site-packages (0.1.2)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in ./anaconda3/lib/python3.10/site-packages (from langchain==0.1.2) (0.6.3)
# Requirement already satisfied: langsmith<0.0.84,>=0.0.83 in ./anaconda3/lib/python3.10/site-packages (from langchain==0.1.2) (0.0.83)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in ./anaconda3/lib/python3.10/site-packages (from langchain==0.1.2) (2.0.27)
# Requirement already satisfied: requests<3,>=2 in ./anaconda3/lib/python3.10/site-packages (from langchain==0.1.2) (2.31.0)
# Requirement already satisfied: langchain-core<0.2,>=0.1.14 in ./anaconda3/lib/python3.10/site-packages (from langchain==0.1.2) (0.1.19)
# Requirement already satisfied: pydantic<3,>=1 in ./anaconda3/lib/python3.10/site-packages (from langchain==0.1.2) (2.4.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in ./anaconda3/lib/python3.10/site-packages (from langchain==0.1.2) (1.33)
# Requirement already satisfied: langchain-community<0.1,>=0.0.14 in ./anaconda3/lib/python3.10/site-packages (from langchain==0.1.2) (0.0.18)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in ./anaconda3/lib/python3.10/site-packages (from langchain==0.1.2) (8.2.3)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in ./anaconda3/lib/python3.10/site-packages (from langchain==0.1.2) (4.0.3)
# Requirement already satisfied: numpy<2,>=1 in ./anaconda3/lib/python3.10/site-packages (from langchain==0.1.2) (1.26.0)
# Requirement already satisfied: PyYAML>=5.3 in ./anaconda3/lib/python3.10/site-packages (from langchain==0.1.2) (6.0.1)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in ./anaconda3/lib/python3.10/site-packages (from langchain==0.1.2) (3.8.5)
# Requirement already satisfied: attrs>=17.3.0 in ./anaconda3/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.2) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in ./anaconda3/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.2) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./anaconda3/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.2) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in ./anaconda3/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.2) (1.9.2)
# Requirement already satisfied: aiosignal>=1.1.2 in ./anaconda3/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.2) (1.3.1)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in ./anaconda3/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.2) (2.0.4)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in ./anaconda3/lib/python3.10/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain==0.1.2) (3.20.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in ./anaconda3/lib/python3.10/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain==0.1.2) (0.9.0)
# Requirement already satisfied: jsonpointer>=1.9 in ./anaconda3/lib/python3.10/site-packages (from jsonpatch<2.0,>=1.33->langchain==0.1.2) (2.1)
# Requirement already satisfied: anyio<5,>=3 in ./anaconda3/lib/python3.10/site-packages (from langchain-core<0.2,>=0.1.14->langchain==0.1.2) (3.5.0)
# Requirement already satisfied: packaging<24.0,>=23.2 in ./anaconda3/lib/python3.10/site-packages (from langchain-core<0.2,>=0.1.14->langchain==0.1.2) (23.2)
# Requirement already satisfied: pydantic-core==2.10.1 in ./anaconda3/lib/python3.10/site-packages (from pydantic<3,>=1->langchain==0.1.2) (2.10.1)
# Requirement already satisfied: annotated-types>=0.4.0 in ./anaconda3/lib/python3.10/site-packages (from pydantic<3,>=1->langchain==0.1.2) (0.6.0)
# Requirement already satisfied: typing-extensions>=4.6.1 in ./anaconda3/lib/python3.10/site-packages (from pydantic<3,>=1->langchain==0.1.2) (4.9.0)
# Requirement already satisfied: idna<4,>=2.5 in ./anaconda3/lib/python3.10/site-packages (from requests<3,>=2->langchain==0.1.2) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./anaconda3/lib/python3.10/site-packages (from requests<3,>=2->langchain==0.1.2) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in ./anaconda3/lib/python3.10/site-packages (from requests<3,>=2->langchain==0.1.2) (2023.7.22)
# Requirement already satisfied: greenlet!=0.4.17 in ./anaconda3/lib/python3.10/site-packages (from SQLAlchemy<3,>=1.4->langchain==0.1.2) (2.0.1)
# Requirement already satisfied: sniffio>=1.1 in ./anaconda3/lib/python3.10/site-packages (from anyio<5,>=3->langchain-core<0.2,>=0.1.14->langchain==0.1.2) (1.2.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in ./anaconda3/lib/python3.10/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain==0.1.2) (1.0.0)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Requirement already satisfied: sentence_transformers==2.2.2 in ./anaconda3/lib/python3.10/site-packages (2.2.2)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in ./anaconda3/lib/python3.10/site-packages (from sentence_transformers==2.2.2) (4.37.2)
# Requirement already satisfied: tqdm in ./anaconda3/lib/python3.10/site-packages (from sentence_transformers==2.2.2) (4.65.0)
# Requirement already satisfied: scikit-learn in ./anaconda3/lib/python3.10/site-packages (from sentence_transformers==2.2.2) (1.2.1)
# Requirement already satisfied: huggingface-hub>=0.4.0 in ./anaconda3/lib/python3.10/site-packages (from sentence_transformers==2.2.2) (0.20.2)
# Requirement already satisfied: sentencepiece in ./anaconda3/lib/python3.10/site-packages (from sentence_transformers==2.2.2) (0.1.99)
# Requirement already satisfied: nltk in ./anaconda3/lib/python3.10/site-packages (from sentence_transformers==2.2.2) (3.7)
# Requirement already satisfied: torchvision in ./anaconda3/lib/python3.10/site-packages (from sentence_transformers==2.2.2) (0.16.2)
# Requirement already satisfied: numpy in ./anaconda3/lib/python3.10/site-packages (from sentence_transformers==2.2.2) (1.26.0)
# Requirement already satisfied: torch>=1.6.0 in ./anaconda3/lib/python3.10/site-packages (from sentence_transformers==2.2.2) (2.1.2)
# Requirement already satisfied: scipy in ./anaconda3/lib/python3.10/site-packages (from sentence_transformers==2.2.2) (1.10.0)
# Requirement already satisfied: requests in ./anaconda3/lib/python3.10/site-packages (from huggingface-hub>=0.4.0->sentence_transformers==2.2.2) (2.31.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in ./anaconda3/lib/python3.10/site-packages (from huggingface-hub>=0.4.0->sentence_transformers==2.2.2) (4.9.0)
# Requirement already satisfied: pyyaml>=5.1 in ./anaconda3/lib/python3.10/site-packages (from huggingface-hub>=0.4.0->sentence_transformers==2.2.2) (6.0.1)
# Requirement already satisfied: fsspec>=2023.5.0 in ./anaconda3/lib/python3.10/site-packages (from huggingface-hub>=0.4.0->sentence_transformers==2.2.2) (2023.10.0)
# Requirement already satisfied: filelock in ./anaconda3/lib/python3.10/site-packages (from huggingface-hub>=0.4.0->sentence_transformers==2.2.2) (3.9.0)
# Requirement already satisfied: packaging>=20.9 in ./anaconda3/lib/python3.10/site-packages (from huggingface-hub>=0.4.0->sentence_transformers==2.2.2) (23.2)
# Requirement already satisfied: networkx in ./anaconda3/lib/python3.10/site-packages (from torch>=1.6.0->sentence_transformers==2.2.2) (2.8.4)
# Requirement already satisfied: sympy in ./anaconda3/lib/python3.10/site-packages (from torch>=1.6.0->sentence_transformers==2.2.2) (1.11.1)
# Requirement already satisfied: jinja2 in ./anaconda3/lib/python3.10/site-packages (from torch>=1.6.0->sentence_transformers==2.2.2) (3.1.2)
# Requirement already satisfied: safetensors>=0.4.1 in ./anaconda3/lib/python3.10/site-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers==2.2.2) (0.4.2)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in ./anaconda3/lib/python3.10/site-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers==2.2.2) (0.15.2)
# Requirement already satisfied: regex!=2019.12.17 in ./anaconda3/lib/python3.10/site-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers==2.2.2) (2023.10.3)
# Requirement already satisfied: click in ./anaconda3/lib/python3.10/site-packages (from nltk->sentence_transformers==2.2.2) (8.1.7)
# Requirement already satisfied: joblib in ./anaconda3/lib/python3.10/site-packages (from nltk->sentence_transformers==2.2.2) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in ./anaconda3/lib/python3.10/site-packages (from scikit-learn->sentence_transformers==2.2.2) (2.2.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in ./anaconda3/lib/python3.10/site-packages (from torchvision->sentence_transformers==2.2.2) (10.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in ./anaconda3/lib/python3.10/site-packages (from jinja2->torch>=1.6.0->sentence_transformers==2.2.2) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in ./anaconda3/lib/python3.10/site-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers==2.2.2) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./anaconda3/lib/python3.10/site-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers==2.2.2) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in ./anaconda3/lib/python3.10/site-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers==2.2.2) (2023.7.22)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./anaconda3/lib/python3.10/site-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers==2.2.2) (2.0.4)
# Requirement already satisfied: mpmath>=0.19 in ./anaconda3/lib/python3.10/site-packages/mpmath-1.2.1-py3.10.egg (from sympy->torch>=1.6.0->sentence_transformers==2.2.2) (1.2.1)

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import os
import glob
import textwrap
import time

# %%
import langchain

# %%
from langchain.document_loaders import PyPDFLoader

# %%
from langchain.document_loaders import DirectoryLoader

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

# %%
from langchain import PromptTemplate, LLMChain

# %%
from langchain.llms import HuggingFacePipeline

# %%
from InstructorEmbedding import INSTRUCTOR

# %%
from langchain.embeddings import HuggingFaceInstructEmbeddings

# %%
from langchain.chains import RetrievalQA

# %%
import torch

# %%
from langchain.vectorstores import FAISS

# %%
class CFG:
    model_name = 'mistralai/Mistral-7B-Instruct-v0.1'
    temperature = 0.5
    top_p = 0.95
    repetition_penalty = 1.15
    do_sample = True
    max_new_tokens = 400
    num_return_sequences=1

    split_chunk_size = 800
    split_overlap = 0
    
    embeddings_model_repo = 'sentence-transformers/all-MiniLM-L6-v2'

    k = 3
    
    PDFs_path = './Python/'
    Embeddings_path =  './faiss_index_py'

# %%
import os
os.environ["HUGGINGFACEHUB_API_TOKEN"] = "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"

# %%
from langchain.llms import HuggingFaceHub

llm = HuggingFaceHub(
    repo_id = CFG.model_name,
    model_kwargs={
        "max_new_tokens": CFG.max_new_tokens,
        "temperature": CFG.temperature,
        "top_p": CFG.top_p,
        "repetition_penalty": CFG.repetition_penalty,
        "do_sample": CFG.do_sample,
        "num_return_sequences": CFG.num_return_sequences
    }
)

# %%
loader = DirectoryLoader(
    CFG.PDFs_path,
    glob="./*.pdf",
    loader_cls=PyPDFLoader,
    show_progress=True,
    use_multithreading=True
)

documents = loader.load()
# Out:
# 100%|█████████████████████████████████████████████| 1/1 [00:03<00:00,  3.13s/it]

# %%
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size = CFG.split_chunk_size,
    chunk_overlap = CFG.split_overlap
)

texts = text_splitter.split_documents(documents)

# %%
embeddings = HuggingFaceInstructEmbeddings(
    model_name = CFG.embeddings_model_repo,
    model_kwargs = {"device": "cpu"}
)

vectordb = FAISS.from_documents(
    documents = texts, 
    embedding = embeddings
)

vectordb.save_local("faiss_index_py")
# Out:
# load INSTRUCTOR_Transformer
# max_seq_length  512

# %%
embeddings = HuggingFaceInstructEmbeddings(
    model_name = CFG.embeddings_model_repo,
    model_kwargs = {"device": "cpu"}
)

vectordb = FAISS.load_local(
    CFG.Embeddings_path,
    embeddings
)
# Out:
# load INSTRUCTOR_Transformer
# max_seq_length  512

# %%
prompt_template = """
<s>[INST] 
Don't try to make up an answer, if you don't know just say that you don't know.
Answer in the same language the question was asked.
Answer the code in python language.
Use only the following pieces of context to answer the question at the end.

{context}

Question: {question}
Answer:[/INST]"""

PROMPT = PromptTemplate(
    template = prompt_template, 
    input_variables = ["question", "context"]
)

# %%
llm_chain = LLMChain(prompt=PROMPT, llm=llm)

# %%
retriever = vectordb.as_retriever(search_kwargs = {"k": CFG.k, "search_type" : "similarity"})

qa_chain = RetrievalQA.from_chain_type(
    llm = llm,
    chain_type = "stuff",
    retriever = retriever, 
    chain_type_kwargs = {"prompt": PROMPT},
    return_source_documents = True,
    verbose = False
)

# %%
def wrap_text_preserve_newlines(text, width=700):
    lines = text.split('\n')

    wrapped_lines = [textwrap.fill(line, width=width) for line in lines]

    wrapped_text = '\n'.join(wrapped_lines)

    return wrapped_text


def process_llm_response(llm_response):
    ans = wrap_text_preserve_newlines(llm_response['result'])
    
    sources_used = ' \n'.join(
        [
            source.metadata['source'].split('/')[-1][:-4] + ' - page: ' + str(source.metadata['page'])
            for source in llm_response['source_documents']
        ]
    )
    
    ans = ans + '\n\nSources: \n' + sources_used
    return ans

# %%
def llm_ans(query):
    start = time.time()
    llm_response = qa_chain(query)
    ans = process_llm_response(llm_response)
    end = time.time()

    time_elapsed = int(round(end - start, 0))
    time_elapsed_str = f'\n\nTime elapsed: {time_elapsed} s'
    return ans.strip() + time_elapsed_str

# %%
def extract_text_after_inst(input_string):
    marker_index = input_string.find("[/INST]")
    
    if marker_index != -1:
        return input_string[marker_index + len("[/INST]"):].strip()
    else:
        return ""

# %%
import gradio as gr

def predict(message, history):
    output = str(llm_ans(message))
    output = extract_text_after_inst(output)
    return output


with gr.Blocks() as demo:
    gr.ChatInterface(
        fn=predict,
        title = f' Open-Source LLM ({CFG.model_name}) for Python Question Answering'
    )
demo.launch()
# Out:
# Running on local URL:  http://127.0.0.1:7874
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7874/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
